# %% [markdown]
# # Machine Learning Assignment 2
# ## Expectation maximization algorithm

# %%
from em_improved_version import EMImprovedVersion
from utils import process_image, plot, error, create_image, get_image
import matplotlib.pyplot as plt
import numpy as np

from tqdm import tqdm

from PIL import Image

# %%
K = [1, 2, 4, 8, 16, 32, 64]
maxIters = 70

path = "im.jpg"
im = Image.open(path)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x690 at 0x212A7728A48>

# %%
im, shape, mode = process_image(im)

# %%
likelihoods_final_ims = []
errors = []
for k in tqdm(K):
    l_im = []
    
    em = EMImprovedVersion(im, k, maxIters)
    
     # run expectation maximization algorithm and get likelihood per iteration
    Ls = em.EM_algorithm()
    l_im.append(Ls) 
    # create image and compute error
    final_im = create_image(em.G, em.M)
    err = error(im, final_im, em.N)
    errors.append(err)
    final_im = get_image(final_im, shape, mode)
    l_im.append(final_im)
    
    likelihoods_final_ims.append(l_im)
# Out:
#  71%|████████████████████████████████████████████████████████████                        | 5/7 [01:38<00:48, 24.09s/it]

# %%
fig, axs = plt.subplots(len(K), 2, figsize=(15, 40))

for i in range(0, len(K)):
    # plot likelihoods
    likelihoods = likelihoods_final_ims[i][0]
    axs[i,0].set_ylabel('likelihood')
    axs[i,0].set_xlabel('iterations')
    x = range(1, len(likelihoods) + 1)
    y = likelihoods
    axs[i,0].plot(x, y)
    
    # plot 
    axs[i,1].axis('off')
    axs[i,1].imshow(likelihoods_final_ims[i][1])
    # show error
    axs[i,1].title.set_text('K: ' + str(K[i]) + ' Error: ' + str(errors[i]))
